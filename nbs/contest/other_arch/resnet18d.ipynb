# %%
#|default_exp challange/timm_upscale

# %% [markdown]
# # Upscale multiarch

# %%
#| export
import pickle,gzip,math,os,time,shutil,torch,random
import fastcore.all as fc,matplotlib as mpl,numpy as np,matplotlib.pyplot as plt
from collections.abc import Mapping
from pathlib import Path
from operator import attrgetter,itemgetter
from functools import partial
from copy import copy
from contextlib import contextmanager

import torchvision.transforms.functional as TF,torch.nn.functional as F
from torchvision import transforms
from torch import tensor,nn,optim
from torch.utils.data import DataLoader,default_collate
from torch.nn import init
from torch.optim import lr_scheduler
from torcheval.metrics import MulticlassAccuracy
from datasets import load_dataset,load_dataset_builder

from miniai.datasets import *
from miniai.conv import *
from miniai.learner import *
from miniai.activations import *
from miniai.init import *
from miniai.sgd import *
from miniai.resnet import *
from miniai.augment import *
from miniai.challange.ct94ep5 import *
from miniai.utils import *
from miniai.accel import *
import timm

# %%
# torch.backends.cudnn.benchmark = True
# torch.backends.cudnn.deterministic = False

# %%
from fastcore.test import test_close
from torch import distributions

torch.set_printoptions(precision=8, linewidth=140, sci_mode=False)
mpl.rcParams['image.cmap'] = 'gray'

import logging
logging.disable(logging.WARNING)

if fc.defaults.cpus>8: fc.defaults.cpus=8

# %%
RNG = RNGSeedCB(verbose=True)
RNG.set_seed(1)
# Out:
# Reseed: 1
# 1

# %%
xl,yl = 'image','label'
name = "fashion_mnist"
bs = 256
xmean,xstd = 0.28, 0.35

@inplace
def transformi(b): b[xl] = [(TF.to_tensor(o)-xmean)/xstd for o in b[xl]]

dsd = load_dataset(name)
tds = dsd.with_transform(transformi)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
tds.cached = cache_dataset_as_dict(tds)

# %%
metrics = LazyMetricsCB(accuracy=MulticlassAccuracy())

def run(model, leaky=0.0003, m=1, cbs=tuple(), fit=True, train_cb=AccelerateCB(), epochs=5, base_lr=2e-2, 
        loss_func=F.cross_entropy, bs=bs, tta=False, dls=None, verbose=False, 
        sched_fn=lr_scheduler.OneCycleLR, opt_func=optim.AdamW):
    iw = partial(init_weights, leaky=leaky) if leaky is not None else fc.noop
    lr = base_lr*m
    print("Batch size", bs*m)
    dls = dls or DataLoaders.from_dd(tds.cached, bs*m, num_workers=0) 
    tmax = epochs * len(dls.train)
    sched = partial(sched_fn, max_lr=lr, total_steps=tmax)
    
    cbs = [DeviceCB(), RNG, metrics, BatchSchedCB(sched), *cbs, train_cb] 
    learn = Learner(model.apply(iw), dls, loss_func, lr=lr, cbs=cbs, opt_func=opt_func)
    if verbose: 
        print(torch.randn([3]))
        print(next(iter(learn.dls.train))[1])
    if fit:
        learn.fit(epochs, cbs=[TimeItCB(), LazyProgressCB(plot=epochs>1)])
    if tta:
        ## TTA
        ap1, at = learn.capture_preds()
        ttacb = BatchTransformCB(partial(tfm_batch, tfm_x=TF.hflip), on_val=True)
        ap2, at = learn.capture_preds(cbs=[ttacb])
        ap = torch.stack([ap1,ap2]).mean(0).argmax(1)
        print('TTA:', round((ap==at).float().mean().item(), 4))
    return learn

# %%
#| export
class Upscale:
    def __init__(self, sz, align=True, const=0): fc.store_attr() 
    def _sz(self, n): return round(self.sz*n / 32)*32 if self.align else self.sz*n
    def antialiased(self, n): 
        return transforms.Resize(self._sz(n), transforms.InterpolationMode.BILINEAR, antialias=True)
    def bilinear(self, n): 
        return transforms.Resize(self._sz(n), transforms.InterpolationMode.BILINEAR, antialias=False)
    def nearest(self, n): 
        return transforms.Resize(self._sz(n), transforms.InterpolationMode.NEAREST)
    def pad(self, n): 
        return transforms.Pad((self._sz(n)-self.sz)//2, padding_mode='constant', fill=self.const)

# %%
upscale32 = Upscale(28, align=True, const=-0.800000011920929)
upscale = Upscale(28, align=False, const=-0.800000011920929)

# %%
RNG.previous()
learn = run(get_model(), epochs=1)
xb,yb = learn.batch
# Out:
# Reseed: 1
# Batch size 256
# Reseed: 1
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.795</td>
#       <td>0.578</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.858</td>
#       <td>0.375</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 1 in: 2.21s, setup: 0.00s, 2.15 ± 0.00s per epoch, 0.01 ± 0.06s per batch

# %%
xb.shape, upscale32.bilinear(4)(xb).shape,upscale32.pad(4)(xb).shape
# Out:
# (torch.Size([272, 1, 28, 28]),
#  torch.Size([272, 1, 128, 128]),
#  torch.Size([272, 1, 128, 128]))

# %%
def show_actual_size(ims):
    sz = ims.shape[-1]
    show_images(ims, imsize=sz / 64)
show_actual_size(xb[:8])

# %%
show_actual_size(upscale.bilinear(2)(xb)[:8])

# %%
show_actual_size(upscale.pad(2)(xb)[:8])

# %%
show_actual_size(upscale.antialiased(2)(xb)[:8])

# %% [markdown]
# ### Timm model upscale, pad, vs noop

# %% [markdown]
# > Changes in batchsize does not have any significant impact on training speed

# %%
#| export
def timm_model(name, resize=nn.Identity(), **kw):
    RNG.previous()
    props = dict(in_chans=1, num_classes=10, pretrained=False)
    props.update(kw)
    model = nn.Sequential( 
        resize,
        timm.create_model(name, **props)
    )
    return dict(model=model)

# %%
#| export
# Cristopher Thomas 94.9% 5epochs
def model9_ct(**kw):
    from miniai.challange.ct94ep5 import get_model9
    RNG.previous()
    return dict(model=get_model9(Mish, norm=nn.BatchNorm2d), base_lr=1e-2, leaky=0.0003) | kw

# %%
#| export
# The last resnet model 92.8% 5epochs
def model_base_resnet():
    from miniai.resnet import get_model
    RNG.previous()
    return dict(model=get_model(act_gr, norm=nn.BatchNorm2d))

# %%
learn = run(**timm_model('resnet18d', nn.Identity()), leaky=0.0, epochs=1)
# Out:
# Batch size 256
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.833</td>
#       <td>0.461</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.895</td>
#       <td>0.286</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 1 in: 5.49s, setup: 0.00s, 5.35 ± 0.00s per epoch, 0.02 ± 0.00s per batch

# %%
learn = run(**timm_model('resnet18d', upscale32.pad(2)), leaky=0.0, epochs=1)
# Out:
# Batch size 256
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.824</td>
#       <td>0.488</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.891</td>
#       <td>0.297</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 1 in: 7.62s, setup: 0.00s, 7.38 ± 0.00s per epoch, 0.03 ± 0.02s per batch

# %%
learn = run(**timm_model('resnet18d', upscale32.nearest(2)), leaky=0.0, epochs=1)
# Out:
# Batch size 256
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.846</td>
#       <td>0.436</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.910</td>
#       <td>0.247</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 1 in: 7.29s, setup: 0.00s, 7.05 ± 0.00s per epoch, 0.03 ± 0.00s per batch

# %%
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), leaky=0.0, epochs=1)
# Out:
# Batch size 256
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.848</td>
#       <td>0.432</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.912</td>
#       <td>0.243</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 1 in: 7.28s, setup: 0.00s, 7.04 ± 0.00s per epoch, 0.03 ± 0.00s per batch

# %%
learn = run(**model_base_resnet(), epochs=1)
# Out:
# Batch size 256
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.813</td>
#       <td>0.520</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.873</td>
#       <td>0.345</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 1 in: 1.63s, setup: 0.00s, 1.57 ± 0.00s per epoch, 0.01 ± 0.00s per batch

# %%
learn = run(**model9_ct(), epochs=1)
# Out:
# Batch size 256
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.871</td>
#       <td>0.460</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.913</td>
#       <td>0.281</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 1 in: 18.38s, setup: 0.00s, 17.53 ± 0.00s per epoch, 0.07 ± 0.02s per batch

# %% [markdown]
# ### 5 Epoch

# %%
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), leaky=0.0)
# Out:
# Batch size 256
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.836</td>
#       <td>0.475</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.781</td>
#       <td>0.706</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.904</td>
#       <td>0.263</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.896</td>
#       <td>0.304</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.925</td>
#       <td>0.202</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.910</td>
#       <td>0.251</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.945</td>
#       <td>0.147</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.931</td>
#       <td>0.195</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.967</td>
#       <td>0.092</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.943</td>
#       <td>0.171</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 37.64s, setup: 0.00s, 7.21 ± 0.13s per epoch, 0.03 ± 0.01s per batch

# %%
learn = run(**model9_ct())
# Out:
# Batch size 256
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.868</td>
#       <td>0.543</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.877</td>
#       <td>0.394</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.909</td>
#       <td>0.289</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.911</td>
#       <td>0.280</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.930</td>
#       <td>0.208</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.918</td>
#       <td>0.232</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.952</td>
#       <td>0.145</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.938</td>
#       <td>0.187</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.975</td>
#       <td>0.083</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.941</td>
#       <td>0.184</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 91.79s, setup: 0.00s, 17.43 ± 0.07s per epoch, 0.07 ± 0.01s per batch

# %%
learn = run(**model_base_resnet())
# Out:
# Batch size 256
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.787</td>
#       <td>0.610</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.848</td>
#       <td>0.426</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.868</td>
#       <td>0.359</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.869</td>
#       <td>0.373</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.891</td>
#       <td>0.296</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.889</td>
#       <td>0.306</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.909</td>
#       <td>0.242</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.900</td>
#       <td>0.283</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.928</td>
#       <td>0.197</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.904</td>
#       <td>0.265</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 9.12s, setup: 0.00s, 1.69 ± 0.01s per epoch, 0.01 ± 0.00s per batch

# %% [markdown]
# # Broken mixup? Curriculum learning for sure

# %% [markdown]
# ## Curriculum learning on FP16
#
# > It doesn't make a difference for fp16

# %%
RNG.set_seed(1)
# Out:
# Reseed: 1
# 1

# %%
learn = run(**model_base_resnet(), 
            dls=CustomDataLoader.from_dd(tds.cached, bs, num_workers=0), cbs=[TopLossesCallback()])
# Out:
# Reseed: 1
# Batch size 256
# Reseed: 1
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.783</td>
#       <td>0.618</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.847</td>
#       <td>0.425</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.866</td>
#       <td>0.362</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.873</td>
#       <td>0.340</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.891</td>
#       <td>0.292</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.892</td>
#       <td>0.300</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.910</td>
#       <td>0.240</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.900</td>
#       <td>0.276</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.929</td>
#       <td>0.195</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.908</td>
#       <td>0.262</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# /home/piotr/miniconda3/envs/miniai/lib/python3.10/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Fit 5 in: 9.87s, setup: 0.02s, 1.81 ± 0.10s per epoch, 0.01 ± 0.00s per batch

# %%
learn = run(**model9_ct(), dls=CustomDataLoader.from_dd(tds.cached, bs, num_workers=0), cbs=[TopLossesCallback()])
# Out:
# Reseed: 1
# Batch size 256
# Reseed: 1
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.865</td>
#       <td>0.553</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.880</td>
#       <td>0.388</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.906</td>
#       <td>0.293</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.899</td>
#       <td>0.310</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.930</td>
#       <td>0.207</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.927</td>
#       <td>0.215</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.952</td>
#       <td>0.142</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.937</td>
#       <td>0.187</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.977</td>
#       <td>0.079</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.939</td>
#       <td>0.186</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 92.02s, setup: 0.00s, 17.49 ± 0.07s per epoch, 0.07 ± 0.00s per batch

# %%
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), leaky=0.0, 
            dls=CustomDataLoader.from_dd(tds.cached, bs, num_workers=0), cbs=[TopLossesCallback()])
# Out:
# Reseed: 1
# Batch size 256
# Reseed: 1
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.835</td>
#       <td>0.479</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.870</td>
#       <td>0.366</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.901</td>
#       <td>0.269</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.873</td>
#       <td>0.372</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.924</td>
#       <td>0.207</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.920</td>
#       <td>0.215</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.946</td>
#       <td>0.147</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.932</td>
#       <td>0.186</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.966</td>
#       <td>0.095</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.939</td>
#       <td>0.175</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 37.33s, setup: 0.00s, 7.12 ± 0.09s per epoch, 0.03 ± 0.00s per batch

# %%
TopLossesCallback??
# Out:
# Init signature: TopLossesCallback()
# Docstring:      <no docstring>
# Source:
# class TopLossesCallback(Callback):
#     def __init__(self):
#         self.epoch_preds = []
#         self.epoch_targets = []
#
#     def before_fit(self, learn):
#         self.epoch_preds = []
#         self.epoch_targets = []
#
#     @torch.no_grad()
#     def _calculate_top_losses(self):
#         preds = torch.cat(self.epoch_preds, dim=0)
#         targets = torch.cat(self.epoch_targets, dim=0)
#         losses = F.cross_entropy(preds, targets, reduce=False)
#         return torch.topk(losses, preds.shape[0]).indices
#
#     def after_batch(self, learn):
#         if learn.training:
#             self.epoch_preds.append(learn.preds)
#             self.epoch_targets.append(learn.batch[1])
#
#     def before_epoch(self,learn):
#         learn.dls.train.sampler.epoch = learn.epoch
#         #print("setting epoch", learn.epoch)
#
#     def after_epoch(self, learn):
#         if self.epoch_preds:
#             #print("after epoch", len(self.epoch_targets))
#             learn.dls.train.sampler.top_losses = self._calculate_top_losses()
#             self.epoch_preds = []
#             self.epoch_targets = []
# File:           ~/workspace/part2/course22p2/miniai/challange/ct94ep5.py
# Type:           type
# Subclasses:

# %%
CustomTrainingSampler??
# Out:
# Init signature: CustomTrainingSampler(*args, **kwargs)
# Docstring:
# Samples elements from ``[0,..,len(weights)-1]`` with given probabilities (weights).
#
# Args:
#     weights (sequence)   : a sequence of weights, not necessary summing up to one
#     num_samples (int): number of samples to draw
#     replacement (bool): if ``True``, samples are drawn with replacement.
#         If not, they are drawn without replacement, which means that when a
#         sample index is drawn for a row, it cannot be drawn again for that row.
#     generator (Generator): Generator used in sampling.
#
# Example:
#     >>> # xdoctest: +IGNORE_WANT("non-deterministic")
#     >>> list(WeightedRandomSampler([0.1, 0.9, 0.4, 0.7, 3.0, 0.6], 5, replacement=True))
#     [4, 4, 1, 4, 5]
#     >>> list(WeightedRandomSampler([0.9, 0.4, 0.05, 0.2, 0.3, 0.1], 5, replacement=False))
#     [0, 1, 4, 3, 2]
# Source:
# class CustomTrainingSampler(WeightedRandomSampler):
#     def __init__(self, *args, **kwargs):
#         WeightedRandomSampler.__init__(self, *args, **kwargs)
#         self.data_indexes_for_epoch = torch.randperm(self.num_samples, generator=self.generator)
#         self.top_losses = self.data_indexes_for_epoch.clone()
#         self.epoch = 0
#         self.n = {
#             0: 0,
#             1: 0.21,
#             2: 0.42,
#             3: 0.21,
#             4: 0
#         }
#
#     def setup_epoch(self, epoch=None):
#         rand_tensor = torch.randperm(self.num_samples, generator=self.generator)
#         n = int(self.n[epoch or self.epoch] * self.num_samples)
#         if n != 0:
#             new_idx = replace_top_losess(n, self.top_losses, self.data_indexes_for_epoch)
#             self.data_indexes_for_epoch = new_idx[rand_tensor]
#         else:
#             self.data_indexes_for_epoch = rand_tensor
#
#
#     def __iter__(self) -> Iterator[int]:
#         self.setup_epoch(self.epoch)
#         yield from self.data_indexes_for_epoch
# File:           ~/workspace/part2/course22p2/miniai/challange/ct94ep5.py
# Type:           type
# Subclasses:

# %%
learn.dls.train.sampler.top_losses
learn.cbs[-2].epoch_preds
learn.dls.train.sampler.epoch
# Out:
# 4

# %% [markdown]
# ### TommyC OneCycleWithPlateau

# %%
#| export
class OneCycleLRWithPlateau(lr_scheduler.OneCycleLR):
    def __init__(self, *args, pct_start=0.1, pct_plateau=0.2, **kwargs):
        kwargs["pct_start"] = pct_start
        super(OneCycleLRWithPlateau, self).__init__(*args, **kwargs)
        self._schedule_phases = [
            {
                'end_step': float(pct_start * self.total_steps) - 1,
                'start_lr': 'initial_lr',
                'end_lr': 'max_lr',
                'start_momentum': 'max_momentum',
                'end_momentum': 'base_momentum',
            },
            {
                'end_step': float((pct_start + pct_plateau) * self.total_steps) - 2,
                'start_lr': 'max_lr',
                'end_lr': 'max_lr',
                'start_momentum': 'base_momentum',
                'end_momentum': 'base_momentum',
            },
            {
                'end_step': self.total_steps - 1,
                'start_lr': 'max_lr',
                'end_lr': 'initial_lr',
                'start_momentum': 'base_momentum',
                'end_momentum': 'max_momentum',
            },
        ]

# %%
# lr=0.02, with Plateau
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), leaky=0.0, 
            dls=CustomDataLoader.from_dd(tds.cached, bs, num_workers=0),
            sched_fn=partial(OneCycleLRWithPlateau, pct_start=0.1, pct_plateau=0.3))
# Out:
# Reseed: 1
# Batch size 256
# Reseed: 1
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.838</td>
#       <td>0.463</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.895</td>
#       <td>0.298</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.911</td>
#       <td>0.246</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.891</td>
#       <td>0.301</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.925</td>
#       <td>0.204</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.911</td>
#       <td>0.244</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.945</td>
#       <td>0.151</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.933</td>
#       <td>0.186</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.965</td>
#       <td>0.094</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.940</td>
#       <td>0.175</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 37.64s, setup: 0.00s, 7.19 ± 0.18s per epoch, 0.03 ± 0.01s per batch

# %%
# lr=0.01 , with Plateau
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), leaky=0.0, 
            base_lr=0.01,
            dls=CustomDataLoader.from_dd(tds.cached, bs, num_workers=0),
            sched_fn=partial(OneCycleLRWithPlateau, pct_start=0.1, pct_plateau=0.3))
# Out:
# Reseed: 1
# Batch size 256
# Reseed: 1
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.827</td>
#       <td>0.502</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.869</td>
#       <td>0.381</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.912</td>
#       <td>0.239</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.913</td>
#       <td>0.238</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.928</td>
#       <td>0.194</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.916</td>
#       <td>0.223</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.949</td>
#       <td>0.140</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.933</td>
#       <td>0.188</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.969</td>
#       <td>0.087</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.942</td>
#       <td>0.172</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 38.09s, setup: 0.00s, 7.27 ± 0.14s per epoch, 0.03 ± 0.01s per batch

# %%
# lr=0.01
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), leaky=0.0, 
            base_lr=0.01,
            dls=CustomDataLoader.from_dd(tds.cached, bs, num_workers=0))
# Out:
# Reseed: 1
# Batch size 256
# Reseed: 1
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.819</td>
#       <td>0.545</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.824</td>
#       <td>0.476</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.902</td>
#       <td>0.265</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.909</td>
#       <td>0.255</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.928</td>
#       <td>0.198</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.923</td>
#       <td>0.211</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.949</td>
#       <td>0.140</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.934</td>
#       <td>0.188</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.968</td>
#       <td>0.090</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.942</td>
#       <td>0.172</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 38.49s, setup: 0.01s, 7.35 ± 0.26s per epoch, 0.03 ± 0.01s per batch

# %%
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), leaky=0.0, 
            base_lr=0.01)
# Out:
# Reseed: 1
# Batch size 256
# Reseed: 1
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.822</td>
#       <td>0.540</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.824</td>
#       <td>0.475</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.904</td>
#       <td>0.263</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.914</td>
#       <td>0.244</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.928</td>
#       <td>0.197</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.912</td>
#       <td>0.249</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.948</td>
#       <td>0.141</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.931</td>
#       <td>0.192</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.968</td>
#       <td>0.088</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.942</td>
#       <td>0.172</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 37.17s, setup: 0.00s, 7.12 ± 0.13s per epoch, 0.03 ± 0.01s per batch

# %% [markdown]
# ### Mixup

# %%
#| export
from miniai.mixup import MixUpCB
class MixUpFP16CB(MixUpCB, AccelerateCB): pass

# %%
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            dls=CustomDataLoader.from_dd(tds.cached, bs, num_workers=0),
            train_cb=MixUpFP16CB(0.4, use_prev=True, label_smoothing=0.1))
# Out:
# Batch size 256
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.775</td>
#       <td>1.212</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.873</td>
#       <td>0.555</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.842</td>
#       <td>1.033</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.892</td>
#       <td>0.418</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.864</td>
#       <td>0.977</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.917</td>
#       <td>0.323</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.886</td>
#       <td>0.936</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.937</td>
#       <td>0.279</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.907</td>
#       <td>0.898</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.944</td>
#       <td>0.259</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 39.19s, setup: 0.00s, 7.49 ± 0.13s per epoch, 0.03 ± 0.01s per batch

# %%
# no curriculum learning
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            train_cb=MixUpFP16CB(0.4, use_prev=True, label_smoothing=0.1))
# Out:
# Reseed: 1
# Batch size 256
# Reseed: 1
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.775</td>
#       <td>1.208</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.715</td>
#       <td>0.948</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.845</td>
#       <td>1.032</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.903</td>
#       <td>0.392</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.863</td>
#       <td>0.983</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.921</td>
#       <td>0.317</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.884</td>
#       <td>0.936</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.930</td>
#       <td>0.294</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.906</td>
#       <td>0.900</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.939</td>
#       <td>0.263</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 37.70s, setup: 0.00s, 7.22 ± 0.15s per epoch, 0.03 ± 0.01s per batch

# %%
# no curriculum learning, no label smoothing
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            train_cb=MixUpFP16CB(0.4, use_prev=True, label_smoothing=0.0))
# Out:
# Reseed: 1
# Batch size 256
# Reseed: 1
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.767</td>
#       <td>0.924</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.757</td>
#       <td>0.834</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.834</td>
#       <td>0.690</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.893</td>
#       <td>0.340</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.855</td>
#       <td>0.620</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.917</td>
#       <td>0.252</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.879</td>
#       <td>0.560</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.926</td>
#       <td>0.215</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.900</td>
#       <td>0.514</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.940</td>
#       <td>0.174</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 37.83s, setup: 0.00s, 7.24 ± 0.10s per epoch, 0.03 ± 0.00s per batch

# %% [markdown]
# ### Mixup + Aug

# %%
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            cbs=[],
            epochs=20, tta=True)
# Out:
# Reseed: 1
# Batch size 256
# Reseed: 1
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.840</td>
#       <td>0.463</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.850</td>
#       <td>0.405</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.902</td>
#       <td>0.269</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.888</td>
#       <td>0.317</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.915</td>
#       <td>0.232</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.895</td>
#       <td>0.291</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.920</td>
#       <td>0.217</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.910</td>
#       <td>0.265</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.929</td>
#       <td>0.196</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.870</td>
#       <td>0.404</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.934</td>
#       <td>0.178</td>
#       <td>5</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.902</td>
#       <td>0.277</td>
#       <td>5</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.941</td>
#       <td>0.157</td>
#       <td>6</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.883</td>
#       <td>0.369</td>
#       <td>6</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.950</td>
#       <td>0.137</td>
#       <td>7</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.921</td>
#       <td>0.245</td>
#       <td>7</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.957</td>
#       <td>0.118</td>
#       <td>8</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.935</td>
#       <td>0.207</td>
#       <td>8</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.961</td>
#       <td>0.105</td>
#       <td>9</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.934</td>
#       <td>0.205</td>
#       <td>9</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.968</td>
#       <td>0.086</td>
#       <td>10</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.930</td>
#       <td>0.234</td>
#       <td>10</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.977</td>
#       <td>0.062</td>
#       <td>11</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.933</td>
#       <td>0.237</td>
#       <td>11</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.982</td>
#       <td>0.049</td>
#       <td>12</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.934</td>
#       <td>0.272</td>
#       <td>12</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.989</td>
#       <td>0.029</td>
#       <td>13</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.942</td>
#       <td>0.270</td>
#       <td>13</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.995</td>
#       <td>0.014</td>
#       <td>14</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.941</td>
#       <td>0.330</td>
#       <td>14</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.999</td>
#       <td>0.004</td>
#       <td>15</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.945</td>
#       <td>0.328</td>
#       <td>15</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>1.000</td>
#       <td>0.001</td>
#       <td>16</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.947</td>
#       <td>0.349</td>
#       <td>16</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>1.000</td>
#       <td>0.000</td>
#       <td>17</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.947</td>
#       <td>0.356</td>
#       <td>17</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>1.000</td>
#       <td>0.000</td>
#       <td>18</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.946</td>
#       <td>0.361</td>
#       <td>18</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>1.000</td>
#       <td>0.000</td>
#       <td>19</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.946</td>
#       <td>0.363</td>
#       <td>19</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 20 in: 147.36s, setup: 0.00s, 7.05 ± 0.08s per epoch, 0.03 ± 0.00s per batch
# Reseed: 1
# Reseed: 1
# TTA: 0.933

# %%
#| export
def tfm_batch(b, tfm_x=fc.noop, tfm_y = fc.noop): return tfm_x(b[0]),tfm_y(b[1])
def get_augcb(*ag):
    tfms = nn.Sequential(*ag)
    return BatchTransformCB(partial(tfm_batch, tfm_x=tfms), on_val=False)

# %%
augcb=get_augcb(transforms.RandomCrop(28, padding=1, fill=-0.800000011920929),
                       transforms.RandomHorizontalFlip(0.5), 
                       RandErase())
mpl.rcParams['image.cmap'] = 'gray_r'

RNG.set_seed()
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, cbs=[augcb],fit=False)
learn.fit(5,cbs=ProgressCB())
learn.show_image_batch(max_n=16,imsize=1)
# Out:
# Reseed: 1688351875
# Reseed: 1688351875
# Batch size 256
# Reseed: 1688351875
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.768</td>
#       <td>0.644</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.752</td>
#       <td>0.758</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.862</td>
#       <td>0.377</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.796</td>
#       <td>0.760</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.894</td>
#       <td>0.284</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.910</td>
#       <td>0.265</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.912</td>
#       <td>0.233</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.919</td>
#       <td>0.235</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.928</td>
#       <td>0.194</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.931</td>
#       <td>0.190</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Reseed: 1688351875

# %%
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            cbs=[get_augcb(transforms.RandomCrop(28, padding=1),transforms.RandomHorizontalFlip(0.65))],
            epochs=5, tta=True)
# Out:
# Reseed: 1688351875
# Batch size 256
# Reseed: 1688351875
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.796</td>
#       <td>0.572</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.812</td>
#       <td>0.566</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.879</td>
#       <td>0.330</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.884</td>
#       <td>0.320</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.908</td>
#       <td>0.249</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.900</td>
#       <td>0.282</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.926</td>
#       <td>0.197</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.926</td>
#       <td>0.204</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.944</td>
#       <td>0.154</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.933</td>
#       <td>0.186</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 37.24s, setup: 0.00s, 7.13 ± 0.14s per epoch, 0.03 ± 0.01s per batch
# Reseed: 1688351875
# Reseed: 1688351875
# TTA: 0.9367

# %%
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            cbs=[get_augcb(transforms.RandomCrop(28, padding=1, fill=-0.800000011920929),
                       transforms.RandomHorizontalFlip(0.65))],
            epochs=5, tta=True)
# Out:
# Reseed: 1688351875
# Batch size 256
# Reseed: 1688351875
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.793</td>
#       <td>0.578</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.831</td>
#       <td>0.445</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.882</td>
#       <td>0.323</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.879</td>
#       <td>0.339</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.907</td>
#       <td>0.248</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.904</td>
#       <td>0.266</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.927</td>
#       <td>0.197</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.928</td>
#       <td>0.199</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.943</td>
#       <td>0.154</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.936</td>
#       <td>0.178</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 37.06s, setup: 0.00s, 7.10 ± 0.04s per epoch, 0.03 ± 0.00s per batch
# Reseed: 1688351875
# Reseed: 1688351875
# TTA: 0.9402

# %%
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            cbs=[get_augcb(transforms.RandomCrop(28, padding=1),
                       transforms.RandomHorizontalFlip(0.65))],
            dls=CustomDataLoader.from_dd(tds.cached, bs, num_workers=0),
            train_cb=MixUpFP16CB(0.4, use_prev=True, label_smoothing=0.1), tta=True)
# Out:
# Reseed: 1688351875
# Batch size 256
# Reseed: 1688351875
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.748</td>
#       <td>1.273</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.761</td>
#       <td>0.747</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.820</td>
#       <td>1.089</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.886</td>
#       <td>0.406</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.843</td>
#       <td>1.025</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.906</td>
#       <td>0.342</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.863</td>
#       <td>0.979</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.917</td>
#       <td>0.313</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.879</td>
#       <td>0.947</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.934</td>
#       <td>0.274</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 39.25s, setup: 0.00s, 7.50 ± 0.19s per epoch, 0.03 ± 0.00s per batch
# Reseed: 1688351875
# Reseed: 1688351875
# TTA: 0.9357

# %%
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            cbs=[get_augcb(transforms.RandomCrop(28, padding=1, fill=-0.800000011920929), 
                       transforms.RandomHorizontalFlip(0.65))],
            train_cb=MixUpFP16CB(0.4, use_prev=True, label_smoothing=0.1), tta=True)
# Out:
# Reseed: 1688351875
# Batch size 256
# Reseed: 1688351875
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.736</td>
#       <td>1.293</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.809</td>
#       <td>0.641</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.818</td>
#       <td>1.093</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.879</td>
#       <td>0.426</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.843</td>
#       <td>1.028</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.910</td>
#       <td>0.362</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.865</td>
#       <td>0.980</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.921</td>
#       <td>0.309</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.882</td>
#       <td>0.945</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.932</td>
#       <td>0.280</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 38.48s, setup: 0.00s, 7.37 ± 0.08s per epoch, 0.03 ± 0.00s per batch
# Reseed: 1688351875
# Reseed: 1688351875
# TTA: 0.934

# %%
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            cbs=[get_augcb(transforms.RandomCrop(28, padding=1, fill=-0.800000011920929), 
                       transforms.RandomHorizontalFlip(0.1))],
            train_cb=MixUpFP16CB(0.4, use_prev=True, label_smoothing=0.1), tta=True)
# Out:
# Reseed: 1688351875
# Batch size 256
# Reseed: 1688351875
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.738</td>
#       <td>1.286</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.851</td>
#       <td>0.608</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.821</td>
#       <td>1.087</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.895</td>
#       <td>0.419</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.844</td>
#       <td>1.022</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.909</td>
#       <td>0.357</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.865</td>
#       <td>0.976</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.928</td>
#       <td>0.300</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.885</td>
#       <td>0.939</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.936</td>
#       <td>0.277</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 38.94s, setup: 0.00s, 7.45 ± 0.23s per epoch, 0.03 ± 0.01s per batch
# Reseed: 1688351875
# Reseed: 1688351875
# TTA: 0.9349

# %%
 learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            cbs=[get_augcb(transforms.RandomCrop(28, padding=1, fill=-0.800000011920929), 
                       transforms.RandomHorizontalFlip(0.1))],
            dls=CustomDataLoader.from_dd(tds.cached, bs, num_workers=0),
            train_cb=MixUpFP16CB(0.4, use_prev=True, label_smoothing=0.1), tta=True)
# Out:
# Reseed: 1688351875
# Batch size 256
# Reseed: 1688351875
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.758</td>
#       <td>1.251</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.810</td>
#       <td>0.606</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.824</td>
#       <td>1.078</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.899</td>
#       <td>0.389</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.847</td>
#       <td>1.017</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.910</td>
#       <td>0.342</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.865</td>
#       <td>0.972</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.919</td>
#       <td>0.313</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.883</td>
#       <td>0.939</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.938</td>
#       <td>0.270</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 5 in: 39.45s, setup: 0.00s, 7.54 ± 0.15s per epoch, 0.03 ± 0.01s per batch
# Reseed: 1688351875
# Reseed: 1688351875
# TTA: 0.9349

# %% [markdown]
# # 20 ep

# %%
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            cbs=[get_augcb(transforms.RandomCrop(28, padding=1),transforms.RandomHorizontalFlip(0.65))],
            epochs=20,
            train_cb=MixUpFP16CB(0.4, use_prev=True, label_smoothing=0.1), tta=True)
# Out:
# Reseed: 1
# Batch size 256
# Reseed: 1
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.749</td>
#       <td>1.267</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.866</td>
#       <td>0.485</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.819</td>
#       <td>1.103</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.875</td>
#       <td>0.443</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.831</td>
#       <td>1.066</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.819</td>
#       <td>0.598</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.842</td>
#       <td>1.036</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.893</td>
#       <td>0.393</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.849</td>
#       <td>1.019</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.909</td>
#       <td>0.408</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.854</td>
#       <td>1.004</td>
#       <td>5</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.913</td>
#       <td>0.367</td>
#       <td>5</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.860</td>
#       <td>0.986</td>
#       <td>6</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.881</td>
#       <td>0.402</td>
#       <td>6</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.865</td>
#       <td>0.977</td>
#       <td>7</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.912</td>
#       <td>0.347</td>
#       <td>7</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.872</td>
#       <td>0.963</td>
#       <td>8</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.926</td>
#       <td>0.288</td>
#       <td>8</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.874</td>
#       <td>0.959</td>
#       <td>9</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.922</td>
#       <td>0.294</td>
#       <td>9</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.878</td>
#       <td>0.946</td>
#       <td>10</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.911</td>
#       <td>0.343</td>
#       <td>10</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.883</td>
#       <td>0.941</td>
#       <td>11</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.930</td>
#       <td>0.290</td>
#       <td>11</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.892</td>
#       <td>0.925</td>
#       <td>12</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.923</td>
#       <td>0.303</td>
#       <td>12</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.897</td>
#       <td>0.915</td>
#       <td>13</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.937</td>
#       <td>0.261</td>
#       <td>13</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.901</td>
#       <td>0.910</td>
#       <td>14</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.943</td>
#       <td>0.256</td>
#       <td>14</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.906</td>
#       <td>0.898</td>
#       <td>15</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.942</td>
#       <td>0.244</td>
#       <td>15</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.913</td>
#       <td>0.887</td>
#       <td>16</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.947</td>
#       <td>0.246</td>
#       <td>16</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.920</td>
#       <td>0.878</td>
#       <td>17</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.950</td>
#       <td>0.235</td>
#       <td>17</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.923</td>
#       <td>0.870</td>
#       <td>18</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.950</td>
#       <td>0.230</td>
#       <td>18</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.922</td>
#       <td>0.871</td>
#       <td>19</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.951</td>
#       <td>0.232</td>
#       <td>19</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>
# Fit 20 in: 153.54s, setup: 0.00s, 7.34 ± 0.07s per epoch, 0.03 ± 0.00s per batch
# Reseed: 1
# Reseed: 1
# TTA: 0.953

# %%
from miniai.mixup import dmce
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            cbs=[get_augcb(transforms.RandomCrop(28, padding=1, fill=-0.800000011920929), 
                       transforms.RandomHorizontalFlip(0.65))],
            epochs=20,
            train_cb=MixUpFP16CB(0.4, use_prev=True, loss_func=dmce, eta=0.1, label_smoothing=0.1), tta=True)

# %%
from miniai.mixup import dmce
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            cbs=[get_augcb(transforms.RandomCrop(28, padding=1, fill=-0.800000011920929), 
                       transforms.RandomHorizontalFlip(0.65))],
            epochs=20,
            train_cb=MixUpFP16CB(0.4, use_prev=True, loss_func=dmce, eta=0.1/4, label_smoothing=0.1), tta=True)

# %%
### EP 50

# %%
from miniai.mixup import dmce
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            cbs=[get_augcb(transforms.RandomCrop(28, padding=1, fill=-0.800000011920929), 
                       transforms.RandomHorizontalFlip(0.65))],
            epochs=50,
            train_cb=MixUpFP16CB(0.4, use_prev=True, eta=0.0, label_smoothing=0.1), tta=True)

# %%
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            cbs=[get_augcb(transforms.RandomCrop(28, padding=1, fill=-0.800000011920929), 
                       transforms.RandomHorizontalFlip(0.65))],
            epochs=20, tta=True)
# Out:
# Reseed: 728734171
# Batch size 256
# Reseed: 728734171
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.00% [3/20 00:22&lt;02:05]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.811</td>
#       <td>0.537</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.842</td>
#       <td>0.430</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.878</td>
#       <td>0.330</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.822</td>
#       <td>0.551</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.894</td>
#       <td>0.288</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.900</td>
#       <td>0.288</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='119' class='' max='235' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.64% [119/235 00:03&lt;00:03]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 learn = run(**timm_model('resnet18d', upscale32.bilinear(2)),
#       2             leaky=0.0,
#       3             cbs=[augcb(transforms.RandomCrop(28, padding=1, fill=-0.800000011920929),transforms.RandomHorizontalFlip(0.65))],
#       4             epochs=20, tta=True)
#
# Cell In[145], line 19, in run(model, leaky, m, cbs, fit, train_cb, epochs, base_lr, loss_func, bs, tta, dls, verbose, sched_fn, opt_func)
#      17     print(next(iter(learn.dls.train))[1])
#      18 if fit:
# ---> 19     learn.fit(epochs, cbs=[TimeItCB(), LazyProgressCB(plot=epochs>1)])
#      20 if tta:
#      21     ## TTA
#      22     ap1, at = learn.capture_preds()
#
# File ~/workspace/part2/course22p2/miniai/learner.py:170, in Learner.fit(self, n_epochs, train, valid, cbs, lr)
#     168     if lr is None: lr = self.lr
#     169     if self.opt_func: self.opt = self.opt_func(self.model.parameters(), lr)
# --> 170     self._fit(train, valid)
#     171 finally:
#     172     for cb in cbs: self.cbs.remove(cb)
#
# File ~/workspace/part2/course22p2/miniai/learner.py:121, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     119 try:
#     120     o.callback(f'before_{self.nm}')
# --> 121     f(o, *args, **kwargs)
#     122     o.callback(f'after_{self.nm}')
#     123 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File ~/workspace/part2/course22p2/miniai/learner.py:158, in Learner._fit(self, train, valid)
#     155 @with_cbs('fit')
#     156 def _fit(self, train, valid):
#     157     for self.epoch in self.epochs:
# --> 158         if train: self.one_epoch(True)
#     159         if valid: torch.no_grad()(self.one_epoch)(False)
#
# File ~/workspace/part2/course22p2/miniai/learner.py:153, in Learner.one_epoch(self, training)
#     151 self.model.train(training)
#     152 self.dl = self.dls.train if training else self.dls.valid
# --> 153 self._one_epoch()
#
# File ~/workspace/part2/course22p2/miniai/learner.py:121, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     119 try:
#     120     o.callback(f'before_{self.nm}')
# --> 121     f(o, *args, **kwargs)
#     122     o.callback(f'after_{self.nm}')
#     123 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File ~/workspace/part2/course22p2/miniai/learner.py:148, in Learner._one_epoch(self)
#     146 @with_cbs('epoch')
#     147 def _one_epoch(self):
# --> 148     for self.iter,self.batch in enumerate(self.dl): self._one_batch()
#
# File ~/workspace/part2/course22p2/miniai/learner.py:121, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     119 try:
#     120     o.callback(f'before_{self.nm}')
# --> 121     f(o, *args, **kwargs)
#     122     o.callback(f'after_{self.nm}')
#     123 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File ~/workspace/part2/course22p2/miniai/learner.py:140, in Learner._one_batch(self)
#     138 self.callback('after_loss')
#     139 if self.training:
# --> 140     self.backward()
#     141     self.callback('after_backward')
#     142     self.step()
#
# File ~/workspace/part2/course22p2/miniai/learner.py:178, in Learner.callback(self, method_nm)
# --> 178 def callback(self, method_nm): run_cbs(self.cbs, method_nm, self)
#
# File ~/workspace/part2/course22p2/miniai/learner.py:35, in run_cbs(cbs, method_nm, learn)
#      33 for cb in sorted(cbs, key=attrgetter('order')):
#      34     method = getattr(cb, method_nm, None)
# ---> 35     if method is not None: method(learn)
#
# File ~/workspace/part2/course22p2/miniai/accel.py:61, in AccelerateCB.backward(self, learn)
# ---> 61 def backward(self, learn): self.acc.backward(learn.loss)
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/accelerate/accelerator.py:1439, in Accelerator.backward(self, loss, **kwargs)
#    1437     return
#    1438 elif self.scaler is not None:
# -> 1439     self.scaler.scale(loss).backward(**kwargs)
#    1440 else:
#    1441     loss.backward(**kwargs)
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/torch/_tensor.py:488, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     478 if has_torch_function_unary(self):
#     479     return handle_torch_function(
#     480         Tensor.backward,
#     481         (self,),
#    (...)
#     486         inputs=inputs,
#     487     )
# --> 488 torch.autograd.backward(
#     489     self, gradient, retain_graph, create_graph, inputs=inputs
#     490 )
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/torch/autograd/__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
learn = run(**timm_model('resnet18d', upscale32.bilinear(2)), 
            leaky=0.0, 
            cbs=[augcb(transforms.RandomCrop(28, padding=1),transforms.RandomHorizontalFlip(0.65))],
            epochs=50, tta=True)
# Out:
# Reseed: 1
# Batch size 256
# Reseed: 1
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='36' class='' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       72.00% [36/50 04:26&lt;01:43]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>accuracy</th>
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.842</td>
#       <td>0.459</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.865</td>
#       <td>0.385</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.911</td>
#       <td>0.245</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.885</td>
#       <td>0.328</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.922</td>
#       <td>0.215</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.882</td>
#       <td>0.330</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.927</td>
#       <td>0.197</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.911</td>
#       <td>0.263</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.933</td>
#       <td>0.182</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.901</td>
#       <td>0.315</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.936</td>
#       <td>0.176</td>
#       <td>5</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.920</td>
#       <td>0.228</td>
#       <td>5</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.940</td>
#       <td>0.164</td>
#       <td>6</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.920</td>
#       <td>0.221</td>
#       <td>6</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.945</td>
#       <td>0.150</td>
#       <td>7</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.922</td>
#       <td>0.231</td>
#       <td>7</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.948</td>
#       <td>0.145</td>
#       <td>8</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.920</td>
#       <td>0.244</td>
#       <td>8</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.950</td>
#       <td>0.136</td>
#       <td>9</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.917</td>
#       <td>0.262</td>
#       <td>9</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.954</td>
#       <td>0.127</td>
#       <td>10</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.917</td>
#       <td>0.251</td>
#       <td>10</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.955</td>
#       <td>0.122</td>
#       <td>11</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.919</td>
#       <td>0.252</td>
#       <td>11</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.960</td>
#       <td>0.110</td>
#       <td>12</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.903</td>
#       <td>0.321</td>
#       <td>12</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.962</td>
#       <td>0.103</td>
#       <td>13</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.924</td>
#       <td>0.257</td>
#       <td>13</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.966</td>
#       <td>0.092</td>
#       <td>14</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.921</td>
#       <td>0.250</td>
#       <td>14</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.968</td>
#       <td>0.089</td>
#       <td>15</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.916</td>
#       <td>0.284</td>
#       <td>15</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.973</td>
#       <td>0.073</td>
#       <td>16</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.915</td>
#       <td>0.356</td>
#       <td>16</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.970</td>
#       <td>0.081</td>
#       <td>17</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.927</td>
#       <td>0.256</td>
#       <td>17</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.977</td>
#       <td>0.062</td>
#       <td>18</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.935</td>
#       <td>0.275</td>
#       <td>18</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.979</td>
#       <td>0.055</td>
#       <td>19</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.927</td>
#       <td>0.318</td>
#       <td>19</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.979</td>
#       <td>0.058</td>
#       <td>20</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.927</td>
#       <td>0.297</td>
#       <td>20</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.983</td>
#       <td>0.049</td>
#       <td>21</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.928</td>
#       <td>0.301</td>
#       <td>21</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.985</td>
#       <td>0.041</td>
#       <td>22</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.923</td>
#       <td>0.344</td>
#       <td>22</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.986</td>
#       <td>0.041</td>
#       <td>23</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.922</td>
#       <td>0.358</td>
#       <td>23</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.986</td>
#       <td>0.039</td>
#       <td>24</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.929</td>
#       <td>0.311</td>
#       <td>24</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.987</td>
#       <td>0.036</td>
#       <td>25</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.936</td>
#       <td>0.300</td>
#       <td>25</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.990</td>
#       <td>0.029</td>
#       <td>26</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.933</td>
#       <td>0.330</td>
#       <td>26</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.991</td>
#       <td>0.027</td>
#       <td>27</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.934</td>
#       <td>0.301</td>
#       <td>27</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.994</td>
#       <td>0.018</td>
#       <td>28</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.936</td>
#       <td>0.328</td>
#       <td>28</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.994</td>
#       <td>0.019</td>
#       <td>29</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.931</td>
#       <td>0.345</td>
#       <td>29</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.995</td>
#       <td>0.013</td>
#       <td>30</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.934</td>
#       <td>0.395</td>
#       <td>30</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.995</td>
#       <td>0.016</td>
#       <td>31</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.937</td>
#       <td>0.362</td>
#       <td>31</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.997</td>
#       <td>0.010</td>
#       <td>32</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.937</td>
#       <td>0.339</td>
#       <td>32</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.998</td>
#       <td>0.005</td>
#       <td>33</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.936</td>
#       <td>0.407</td>
#       <td>33</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.997</td>
#       <td>0.009</td>
#       <td>34</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.937</td>
#       <td>0.385</td>
#       <td>34</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.998</td>
#       <td>0.006</td>
#       <td>35</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.937</td>
#       <td>0.391</td>
#       <td>35</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='11' class='' max='235' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       4.68% [11/235 00:00&lt;00:06]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 learn = run(**timm_model('resnet18d', upscale32.bilinear(2)),
#       2             leaky=0.0,
#       3             cbs=[augcb(transforms.RandomCrop(28, padding=1),transforms.RandomHorizontalFlip(0.65))],
#       4             epochs=50, tta=True)
#
# Cell In[145], line 19, in run(model, leaky, m, cbs, fit, train_cb, epochs, base_lr, loss_func, bs, tta, dls, verbose, sched_fn, opt_func)
#      17     print(next(iter(learn.dls.train))[1])
#      18 if fit:
# ---> 19     learn.fit(epochs, cbs=[TimeItCB(), LazyProgressCB(plot=epochs>1)])
#      20 if tta:
#      21     ## TTA
#      22     ap1, at = learn.capture_preds()
#
# File ~/workspace/part2/course22p2/miniai/learner.py:170, in Learner.fit(self, n_epochs, train, valid, cbs, lr)
#     168     if lr is None: lr = self.lr
#     169     if self.opt_func: self.opt = self.opt_func(self.model.parameters(), lr)
# --> 170     self._fit(train, valid)
#     171 finally:
#     172     for cb in cbs: self.cbs.remove(cb)
#
# File ~/workspace/part2/course22p2/miniai/learner.py:121, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     119 try:
#     120     o.callback(f'before_{self.nm}')
# --> 121     f(o, *args, **kwargs)
#     122     o.callback(f'after_{self.nm}')
#     123 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File ~/workspace/part2/course22p2/miniai/learner.py:158, in Learner._fit(self, train, valid)
#     155 @with_cbs('fit')
#     156 def _fit(self, train, valid):
#     157     for self.epoch in self.epochs:
# --> 158         if train: self.one_epoch(True)
#     159         if valid: torch.no_grad()(self.one_epoch)(False)
#
# File ~/workspace/part2/course22p2/miniai/learner.py:153, in Learner.one_epoch(self, training)
#     151 self.model.train(training)
#     152 self.dl = self.dls.train if training else self.dls.valid
# --> 153 self._one_epoch()
#
# File ~/workspace/part2/course22p2/miniai/learner.py:121, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     119 try:
#     120     o.callback(f'before_{self.nm}')
# --> 121     f(o, *args, **kwargs)
#     122     o.callback(f'after_{self.nm}')
#     123 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File ~/workspace/part2/course22p2/miniai/learner.py:148, in Learner._one_epoch(self)
#     146 @with_cbs('epoch')
#     147 def _one_epoch(self):
# --> 148     for self.iter,self.batch in enumerate(self.dl): self._one_batch()
#
# File ~/workspace/part2/course22p2/miniai/learner.py:121, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     119 try:
#     120     o.callback(f'before_{self.nm}')
# --> 121     f(o, *args, **kwargs)
#     122     o.callback(f'after_{self.nm}')
#     123 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File ~/workspace/part2/course22p2/miniai/learner.py:135, in Learner._one_batch(self)
#     133 @with_cbs('batch')
#     134 def _one_batch(self):
# --> 135     self.predict()
#     136     self.callback('after_predict')
#     137     self.get_loss()
#
# File ~/workspace/part2/course22p2/miniai/learner.py:178, in Learner.callback(self, method_nm)
# --> 178 def callback(self, method_nm): run_cbs(self.cbs, method_nm, self)
#
# File ~/workspace/part2/course22p2/miniai/learner.py:35, in run_cbs(cbs, method_nm, learn)
#      33 for cb in sorted(cbs, key=attrgetter('order')):
#      34     method = getattr(cb, method_nm, None)
# ---> 35     if method is not None: method(learn)
#
# File ~/workspace/part2/course22p2/miniai/learner.py:85, in TrainCB.predict(self, learn)
# ---> 85 def predict(self, learn): learn.preds = learn.model(*learn.batch[:self.n_inp])
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/accelerate/utils/operations.py:489, in ConvertOutputsToFp32.__call__(self, *args, **kwargs)
#     488 def __call__(self, *args, **kwargs):
# --> 489     return convert_to_fp32(self.model_forward(*args, **kwargs))
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/torch/amp/autocast_mode.py:14, in autocast_decorator.<locals>.decorate_autocast(*args, **kwargs)
#      11 @functools.wraps(func)
#      12 def decorate_autocast(*args, **kwargs):
#      13     with autocast_instance:
# ---> 14         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/torch/nn/modules/container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/timm/models/resnet.py:730, in ResNet.forward(self, x)
#     729 def forward(self, x):
# --> 730     x = self.forward_features(x)
#     731     x = self.forward_head(x)
#     732     return x
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/timm/models/resnet.py:720, in ResNet.forward_features(self, x)
#     718     x = self.layer2(x)
#     719     x = self.layer3(x)
# --> 720     x = self.layer4(x)
#     721 return x
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/torch/nn/modules/container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/timm/models/resnet.py:392, in BasicBlock.forward(self, x)
#     389     x = self.drop_path(x)
#     391 if self.downsample is not None:
# --> 392     shortcut = self.downsample(shortcut)
#     393 x += shortcut
#     394 x = self.act2(x)
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/torch/nn/modules/container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/torch/nn/modules/conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniconda3/envs/miniai/lib/python3.10/site-packages/torch/nn/modules/conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
learn = run(**timm_model('resnet50d', upscale32.bilinear(2)), 
            leaky=0.0, 
            cbs=[augcb(transforms.RandomCrop(28, padding=1),transforms.RandomHorizontalFlip(0.65))],
            epochs=50, tta=True)
